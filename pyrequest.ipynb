# %%
import requests 
import os

# %%
r = requests.get('https://postman-echo.com/get?foo1=bar1&foo2=bar2', auth=('user','pass'))

# %%
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '{"args":{"foo1":"bar1","foo2":"bar2"},"headers":{"x-forwarded-proto":"https","x-forwarded-port":"443","host":"postman-echo.com","x-amzn-trace-id":"Root=1-5f96f38f-2017e74b68bd318c5aca48b2","user-agent":"python-requests/2.24.0","accept-encoding":"gzip, deflate","accept":"*/*","authorization":"Basic dXNlcjpwYXNz"},"url":"https://postman-echo.com/get?foo1=bar1&foo2=bar2"}'

# %%
r.encoding
# Out:
# 'utf-8'

# %%
s = requests.get('https://api.github.com/events')

# %%
s.text
# Out:
# '[{"id":"13974406140","type":"PushEvent","actor":{"id":959867,"login":"danielflanigan","display_login":"danielflanigan","gravatar_id":"","url":"https://api.github.com/users/danielflanigan","avatar_url":"https://avatars.githubusercontent.com/u/959867?"},"repo":{"id":125331236,"name":"danielflanigan/layouteditor-wrapper","url":"https://api.github.com/repos/danielflanigan/layouteditor-wrapper"},"payload":{"push_id":5920709043,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"2c8b172c7e95749bc46bbeca748888b76cc37427","before":"8d9096397751bc451b5ecf26a77b60767d54a260","commits":[{"sha":"2c8b172c7e95749bc46bbeca748888b76cc37427","author":{"email":"daniel.isaiah.flanigan@gmail.com","name":"Daniel Flanigan"},"message":".readthedocs.yml: attempt to install package 2.","distinct":true,"url":"https://api.github.com/repos/danielflanigan/layouteditor-wrapper/commits/2c8b172c7e95749bc46bbeca748888b76cc37427"}]},"public":true,"created_at":"2020-10-26T15:59:42Z"},{"id":"13974406137","typ
# ...

# %%
r = requests.post('https://httpbin.org/post', data = {'1':'this is a test description'})

# %%
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "1": "this is a test description"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "28", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.24.0", \n    "X-Amzn-Trace-Id": "Root=1-5f96f3c9-627d01b7670f94717c627f43"\n  }, \n  "json": null, \n  "origin": "49.36.7.221", \n  "url": "https://httpbin.org/post"\n}\n'
